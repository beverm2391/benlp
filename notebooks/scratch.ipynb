# %%
from benlp.tools.code_executor import execute_code
import json

# %%
code = """
import matplotlib.pyplot as plt
import numpy as np

# Define the demand and supply functions
def demand(x):
    return 10 - x

def supply(x):
    return x

# Generate x values
x = np.linspace(0, 10, 100)

# Generate y values for demand and supply
y_demand = demand(x)
y_supply = supply(x)

# Create the plot
plt.figure(figsize=(8, 6))
plt.plot(x, y_demand, label='Demand')
plt.plot(x, y_supply, label='Supply')

# Add labels and title
plt.xlabel('Quantity')
plt.ylabel('Price')
plt.title('Supply and Demand Curves')
plt.legend()

# Show the plot
plt.show()
"""

json_ = json.dumps({"code" : code})

# %%
print(json_)
# Out:
# {"code": "\nimport matplotlib.pyplot as plt\nimport numpy as np\n\n# Define the demand and supply functions\ndef demand(x):\n    return 10 - x\n\ndef supply(x):\n    return x\n\n# Generate x values\nx = np.linspace(0, 10, 100)\n\n# Generate y values for demand and supply\ny_demand = demand(x)\ny_supply = supply(x)\n\n# Create the plot\nplt.figure(figsize=(8, 6))\nplt.plot(x, y_demand, label='Demand')\nplt.plot(x, y_supply, label='Supply')\n\n# Add labels and title\nplt.xlabel('Quantity')\nplt.ylabel('Price')\nplt.title('Supply and Demand Curves')\nplt.legend()\n\n# Show the plot\nplt.show()\n"}

# %%
output = execute_code(code)

# %%
# Out:
# ''
